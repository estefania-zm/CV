# %% [markdown]
# # Visualización de series de tiempo para acciones en la bolsa

# %% [markdown]
# * En este ejercico se practicó la visualización de datos temporales con un enfoque financiero.
# _______________________________________________________________________________________________

# %% [markdown]
# ### Setup

# %%
import pandas as pd
import numpy as np
import os
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# _______________________________________________________________________________________________________
# ### Lectura del archivo

# %%
os.chdir('C:/Users/estef/Desktop/data')
df = pd.read_csv('SP500_HIST.csv', index_col = 'Date', parse_dates = ['Date'])
df.sample(5)
# Out:
#             Close/Last     Open     High      Low
# Date
# 2019-09-03     2906.27  2909.01  2914.39  2891.85
# 2019-04-04     2879.39  2873.99  2881.28  2867.14
# 2023-09-29     4288.05  4328.18  4333.15  4274.86
# 2020-07-16     3215.57  3208.36  3220.39  3198.59
# 2015-05-07     2088.00  2079.96  2092.90  2074.99

# %%
df
#Tenemos datos históricos de las acciones de SP500 desde 09/oct/2014 hasta 08/oct/2024
# Out:
#             Close/Last     Open     High      Low
# Date
# 2024-10-08     5751.13  5719.14  5757.60  5714.56
# 2024-10-07     5695.94  5737.80  5739.34  5686.85
# 2024-10-04     5751.07  5737.48  5753.21  5702.83
# 2024-10-03     5699.94  5698.19  5718.78  5677.37
# 2024-10-02     5709.54  5698.14  5719.63  5674.00
# ...                ...      ...      ...      ...
# 2014-10-15     1862.49  1874.18  1874.18  1820.66
# 2014-10-14     1877.70  1877.11  1898.71  1871.79
# 2014-10-13     1874.74  1905.65  1912.09  1874.14
# 2014-10-10     1906.13  1925.63  1936.98  1906.05
# 2014-10-09     1928.21  1967.68  1967.68  1927.56
#
# [2527 rows x 4 columns]

# %%
# Cambio de nombre de columna Close/Last para facilitar su manejo
df.rename(columns={'Close/Last': 'Close'}, inplace=True)

# %% [markdown]
# ______________________________________________________________________________________________________
# ### Análisis univariado

# %%
df.shape
# Out:
# (2527, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2527 entries, 2024-10-08 to 2014-10-09
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2527 non-null   float64
#  1   Open    2527 non-null   float64
#  2   High    2527 non-null   float64
#  3   Low     2527 non-null   float64
# dtypes: float64(4)
# memory usage: 98.7 KB

# %%
# Cambiar formato de pandas para una visualización más amigable
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df.describe().T
# Out:
#         count    mean     std     min     25%     50%     75%     max
# Close 2527.00 3260.71 1028.29 1829.08 2362.77 2932.47 4145.39 5762.48
# Open  2527.00 3251.22 1047.29    0.00 2362.73 2930.91 4139.93 5762.22
# High  2527.00 3268.64 1052.96    0.00 2368.82 2944.25 4167.10 5767.37
# Low   2527.00 3232.50 1041.45    0.00 2351.30 2917.91 4119.18 5727.34

# %%
# Contar ceros
df[df==0].count() / df.count()
# Out:
# Close   0.00
# Open    0.00
# High    0.00
# Low     0.00
# dtype: float64

# %% [markdown]
# ### Visualización de series de tiempo

# %%
df
# Out:
#              Close    Open    High     Low
# Date
# 2024-10-08 5751.13 5719.14 5757.60 5714.56
# 2024-10-07 5695.94 5737.80 5739.34 5686.85
# 2024-10-04 5751.07 5737.48 5753.21 5702.83
# 2024-10-03 5699.94 5698.19 5718.78 5677.37
# 2024-10-02 5709.54 5698.14 5719.63 5674.00
# ...            ...     ...     ...     ...
# 2014-10-15 1862.49 1874.18 1874.18 1820.66
# 2014-10-14 1877.70 1877.11 1898.71 1871.79
# 2014-10-13 1874.74 1905.65 1912.09 1874.14
# 2014-10-10 1906.13 1925.63 1936.98 1906.05
# 2014-10-09 1928.21 1967.68 1967.68 1927.56
#
# [2527 rows x 4 columns]

# %%
df = df.sort_index()
df['2014':'2024'].plot(subplots = True, figsize=(10,12))
plt.title('Precios 2014 - 2024 SP500')
plt.show()

# %% [markdown]
# ### Visualización de lags

# %%
df['Close'].asfreq('M').plot(legend=True)
lag = 3
shifted = df['Close'].asfreq('M').shift(lag).plot(legend=True)
shifted.legend(['SP500 Close','SP500 Lagged'])
plt.grid()
plt.show()
# Out:
# C:\Users\estef\AppData\Local\Temp\ipykernel_12824\93044238.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df['Close'].asfreq('M').plot(legend=True)
# C:\Users\estef\AppData\Local\Temp\ipykernel_12824\93044238.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   shifted = df['Close'].asfreq('M').shift(lag).plot(legend=True)

# %%
df['Change'] = df.Close.div(df.Close.shift())
df
# Out:
#              Close    Open    High     Low  Change
# Date
# 2014-10-09 1928.21 1967.68 1967.68 1927.56     NaN
# 2014-10-10 1906.13 1925.63 1936.98 1906.05    0.99
# 2014-10-13 1874.74 1905.65 1912.09 1874.14    0.98
# 2014-10-14 1877.70 1877.11 1898.71 1871.79    1.00
# 2014-10-15 1862.49 1874.18 1874.18 1820.66    0.99
# ...            ...     ...     ...     ...     ...
# 2024-10-02 5709.54 5698.14 5719.63 5674.00    1.00
# 2024-10-03 5699.94 5698.19 5718.78 5677.37    1.00
# 2024-10-04 5751.07 5737.48 5753.21 5702.83    1.01
# 2024-10-07 5695.94 5737.80 5739.34 5686.85    0.99
# 2024-10-08 5751.13 5719.14 5757.60 5714.56    1.01
#
# [2527 rows x 5 columns]

# %%
df['Change'].plot(figsize = (20,8)).grid()

# %%
df['Return'] = df.Change.sub(1).mul(100)
df
# Out:
#              Close    Open    High     Low  Change  Return
# Date
# 2014-10-09 1928.21 1967.68 1967.68 1927.56     NaN     NaN
# 2014-10-10 1906.13 1925.63 1936.98 1906.05    0.99   -1.15
# 2014-10-13 1874.74 1905.65 1912.09 1874.14    0.98   -1.65
# 2014-10-14 1877.70 1877.11 1898.71 1871.79    1.00    0.16
# 2014-10-15 1862.49 1874.18 1874.18 1820.66    0.99   -0.81
# ...            ...     ...     ...     ...     ...     ...
# 2024-10-02 5709.54 5698.14 5719.63 5674.00    1.00    0.01
# 2024-10-03 5699.94 5698.19 5718.78 5677.37    1.00   -0.17
# 2024-10-04 5751.07 5737.48 5753.21 5702.83    1.01    0.90
# 2024-10-07 5695.94 5737.80 5739.34 5686.85    0.99   -0.96
# 2024-10-08 5751.13 5719.14 5757.60 5714.56    1.01    0.97
#
# [2527 rows x 6 columns]

# %%
df['Return'].plot(figsize=(20,8)).grid()

# %% [markdown]
# ### Comparación de series

# %%
#Lectura del segundo archivo (Histórico de precios Nikkei225)
df2 = pd.read_csv('NIKKEI225_HIST.csv', index_col = 'Date', parse_dates = ['Date'])
df2
# Out:
#                  Open       High        Low      Close
# Date
# 2024-10-08  39,021.13  39,117.09  38,817.54  38,937.54
# 2024-10-07  39,239.92  39,560.78  39,195.93  39,332.74
# 2024-10-04  38,594.73  38,735.29  38,501.82  38,635.62
# 2024-10-03  38,459.13  38,856.75  38,457.62  38,552.06
# 2024-10-02  38,136.20  38,213.54  37,651.07  37,808.76
# ...               ...        ...        ...        ...
# 2014-10-07  15,841.17  15,913.52  15,755.57  15,783.83
# 2014-10-06  15,882.28  15,970.65  15,808.22  15,890.95
# 2014-10-03  15,616.48  15,708.65  15,559.07  15,708.65
# 2014-10-02  15,895.20  15,922.51  15,646.40  15,661.99
# 2014-10-01  16,173.39  16,225.96  16,081.01  16,082.25
#
# [2470 rows x 4 columns]

# %%
# Verificar si hay nulos en df2
df2.isnull().sum()
# Out:
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
df2[df2.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close]
# Index: []

# %%
#Se identifican valores con falta de información indicada con '-'
df2[df2.apply(lambda x: x.str.contains('-').any(), axis=1)]
# Out:
#            Open High Low Close
# Date
# 2018-12-31    -    -   -     -
# 2018-12-24    -    -   -     -
# 2018-11-23    -    -   -     -
# 2018-10-08    -    -   -     -
# 2018-09-24    -    -   -     -
# 2018-09-17    -    -   -     -
# 2018-05-04    -    -   -     -
# 2018-05-03    -    -   -     -
# 2018-04-30    -    -   -     -
# 2018-03-21    -    -   -     -
# 2018-02-12    -    -   -     -
# 2018-01-08    -    -   -     -
# 2018-01-03    -    -   -     -
# 2018-01-02    -    -   -     -
# 2018-01-01    -    -   -     -
# 2017-11-23    -    -   -     -
# 2017-11-03    -    -   -     -
# 2017-10-09    -    -   -     -
# 2017-09-18    -    -   -     -
# 2017-08-11    -    -   -     -
# 2017-07-17    -    -   -     -

# %%
df2.info()
# Las variables serán transformadas en valores de tipo numérico
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2470 entries, 2024-10-08 to 2014-10-01
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2470 non-null   object
#  1   High    2470 non-null   object
#  2   Low     2470 non-null   object
#  3   Close   2470 non-null   object
# dtypes: object(4)
# memory usage: 96.5+ KB

# %%
df2 = df2.replace({'-': np.nan}) #convertir valores '-' por NaN para despues eliminarlos
df2 = df2.replace({',': ''}, regex=True)  # Eliminar las comas en todas las columnas para poder transformar en valores numéricos
df2.dropna(axis=0, inplace=True) #Eliminar valores NaN
df2[['Open', 'High', 'Low', 'Close']] = df2[['Open', 'High', 'Low', 'Close']].astype('float') #Transformar a variables numéricas
df2.sort_index(inplace=True) #Ordenar index (Date) cronologicamente
df2
# Out:
#                Open     High      Low    Close
# Date
# 2014-10-01 16173.39 16225.96 16081.01 16082.25
# 2014-10-02 15895.20 15922.51 15646.40 15661.99
# 2014-10-03 15616.48 15708.65 15559.07 15708.65
# 2014-10-06 15882.28 15970.65 15808.22 15890.95
# 2014-10-07 15841.17 15913.52 15755.57 15783.83
# ...             ...      ...      ...      ...
# 2024-10-02 38136.20 38213.54 37651.07 37808.76
# 2024-10-03 38459.13 38856.75 38457.62 38552.06
# 2024-10-04 38594.73 38735.29 38501.82 38635.62
# 2024-10-07 39239.92 39560.78 39195.93 39332.74
# 2024-10-08 39021.13 39117.09 38817.54 38937.54
#
# [2449 rows x 4 columns]

# %%
# Visualización de los datos
df2['2014':'2024'].plot(subplots = True, figsize=(10,12))
plt.title('Precios 2014 - 2024 NIKKEI225')
plt.show()

# %%
df.Close.plot()
df2.Close.plot()
plt.legend(['SP500','NIKKEI225'])
plt.title('Comparación precios historicos SP500 vs NIKKEI 2014-2024')
# Out:
# Text(0.5, 1.0, 'Comparación precios historicos SP500 vs NIKKEI 2014-2024')

# %%
normal_sp = df.Close.div(df.Close.iloc[0]).mul(100)
normal_nk = df2.Close.div(df2.Close.iloc[0]).mul(100)
normal_sp.plot()
normal_nk.plot()
plt.legend(('SP500','NIKKEI225'))
plt.title('Comparación SP500 vs NIKKEI225 normalizados')
# Out:
# Text(0.5, 1.0, 'Comparación SP500 vs NIKKEI225 normalizados')

# %% [markdown]
# ### Visualización de medias

# %%
roll_sp = df.Close.rolling('90D').mean()
df.Close.plot()
roll_sp.plot()
plt.title('Precio dde cierre vs Media movil 90D SP500')
plt.legend(['High','Rolling Mean'])

# %% [markdown]
# ### Visualizaciones financieras

# %%
#Se importan librerías de base 
# %matplotlib inline 
from pylab import rcParams

#Instala chart_studio 
from chart_studio import plotly 
from chart_studio import grid_objs 
import chart_studio.plotly as py 
from plotly.offline import init_notebook_mode, iplot 
init_notebook_mode(connected=True)

#from plotly import tools 
import chart_studio.plotly as py 
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go 
import plotly.figure_factory as ff 
import statsmodels.api as sm
from numpy.random import normal, seed 
from scipy.stats import norm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import math
from sklearn.metrics import mean_squared_error
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.34.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.34.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #### Gráfico OHLC

# %%
df_jun = df.loc['2015-06']
rango_ohlc = go.Ohlc(x=df_jun.index,
                     open=df_jun['Open'],
                     high=df_jun['High'],
                     low=df_jun['Low'],
                     close=df_jun['Close'])

data = [rango_ohlc]

# Mostrar gráfico
iplot(data)
# Out:
# <div>                            <div id="f7dba739-8610-4e55-be71-695dd57c67f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7dba739-8610-4e55-be71-695dd57c67f3")) {                    Plotly.newPlot(                        "f7dba739-8610-4e55-be71-695dd57c67f3",                        [{"close":[2111.73,2109.6,2114.07,2095.84,2092.83,2079.28,2080.15,2105.2,2108.86,2094.11,2084.43,2096.29,2100.44,2121.24,2109.99,2122.85,2124.2,2108.58,2102.31,2101.49,2057.64,2063.11],"high":[2119.15,2117.59,2121.92,2112.89,2100.99,2093.01,2085.62,2108.5,2115.02,2107.43,2091.34,2097.4,2106.79,2126.65,2121.64,2129.87,2128.03,2125.1,2116.04,2108.92,2098.63,2074.28],"low":[2102.54,2099.14,2109.61,2093.23,2085.67,2079.11,2072.14,2081.12,2106.24,2091.33,2072.49,2082.1,2088.86,2101.58,2109.45,2112.5,2119.89,2108.58,2101.78,2095.38,2056.64,2056.32],"open":[2108.64,2110.41,2110.64,2112.35,2095.09,2092.34,2079.07,2081.12,2106.24,2107.43,2091.34,2084.26,2097.4,2101.58,2121.06,2112.5,2123.16,2123.65,2109.96,2102.62,2098.63,2061.19],"x":["2015-06-01T00:00:00","2015-06-02T00:00:00","2015-06-03T00:00:00","2015-06-04T00:00:00","2015-06-05T00:00:00","2015-06-08T00:00:00","2015-06-09T00:00:00","2015-06-10T00:00:00","2015-06-11T00:00:00","2015-06-12T00:00:00","2015-06-15T00:00:00","2015-06-16T00:00:00","2015-06-17T00:00:00","2015-06-18T00:00:00","2015-06-19T00:00:00","2015-06-22T00:00:00","2015-06-23T00:00:00","2015-06-24T00:00:00","2015-06-25T00:00:00","2015-06-26T00:00:00","2015-06-29T00:00:00","2015-06-30T00:00:00"],"type":"ohlc"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9 ...

# %%
df_17 = df.loc['2017']
trace = go.Ohlc(x=df_17.index,
                     open=df_17['Open'],
                     high=df_17['High'],
                     low=df_17['Low'],
                     close=df_17['Close'])

data = [trace]

# Mostrar gráfico
iplot(data, filename='simple_ohlc')
# Out:
# <div>                            <div id="e9192f7c-d9a0-4394-ab61-607a87851113" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9192f7c-d9a0-4394-ab61-607a87851113")) {                    Plotly.newPlot(                        "e9192f7c-d9a0-4394-ab61-607a87851113",                        [{"close":[2257.83,2270.75,2269.0,2276.98,2268.9,2268.9,2275.32,2270.44,2274.64,2267.89,2271.89,2263.69,2271.31,2265.2,2280.07,2298.37,2296.68,2294.69,2280.9,2278.87,2279.55,2280.85,2297.42,2292.56,2293.08,2294.67,2307.87,2316.1,2328.25,2337.58,2349.25,2347.22,2351.16,2365.38,2362.82,2363.81,2367.34,2369.75,2363.64,2395.96,2381.92,2383.12,2375.31,2368.39,2362.98,2364.87,2372.6,2373.47,2365.45,2385.26,2381.38,2378.25,2373.47,2344.02,2348.45,2345.96,2343.98,2341.59,2358.57,2361.13,2368.06,2362.72,2358.84,2360.16,2352.95,2357.49,2355.54,2357.16,2353.78,2344.93,2328.95,2349.01,2342.19,2338.17,2355.84,2348.69,2374.15,2388.61,2387.45,2388.77,2384.2,2388.33,2391.17,2388.13,2389.52,2399.29,2399.38,2396.92,2399.63,2394.44,2390.9,2402.32,2400.67,2357.03,2365.72,2381.73,2394.02,2398.42,2404.39,2415.07,2415.82,2412.91,2411.8,2430.06,2439.07,2436.1,2429.33,2433.14,2433.79,2431.77,2429.39,2440.35,2437.92,2432.46,2433.15,2453.46,2437.03,2435.61,2434.5,2438.3,2439.07,2419.38,2440.69,2419.7,2423.41,2429.01,2432.54,2409.75,2425.18,2427.43,2425.53,2443.25,2447.83,2459.27,2459.14,2460.61,2473.83,2473.45,2472.54,2469.91,2477.13,2477.83,2475.42,2472.1,2470.3,2476.35,2477.57,2472.16,2476.83,2480.91,2474.92,2474.02,2438.21,2441.32,2465.84,2464.61,2468.11,2430.01,2425.55,2428.37,2452.51,2444.04,2438.97,2443.05,2444.24,2446.3,2457.59,2471.65,2476.55,2457.85,2465.54,2465.1,2461.43,2488.11,2496.48,2498.37,2495.62,2500.23,2503.87,2506.65,2508.24,2500.6,2502.22,2496.66,2496.84,2507.04,2510.06,2519.36,2529.12,2534.58,2537.74,2552.07,2549.33,2544.73,2550.64,2555.24,2550.93,2553.17,2557.64,2559.36,2561.26,2562.1,2575.21,2564.98,2569.13,2557.15,2560.4,2581.07,2572.83,2575.26,2579.36,2579.85,2587.84,2591.13,2590.64,2594.38,2584.62,2582.3,2584.84,2578.87,2564.62,2585.64,2578.85,2582.14,2599.03,2597.08,2602.42,2601.42,2627.04,2626.07,2647.58,2642.22,2639.44,2629.57,2629.27,2636.98,2651.5,2659.99,2664.11,2662.85,2652.01,2675.81,2690.16,2681.47,2679.25,2684.57,2683.34,2680.5,2682.62,2687.54,2673.61],"high":[2263.88,2272.82,2271.5,2282.1,2275.49,2279.27,2275.32,2271.78,2278.68,2272.08,2272.01,2274.33,2276.96,2271.78,2284.63,2299.55,2300.99,2299.02,2286.01,2279.09,2289.14,2283.97,2298.31,2296.18,2299.4,2295.91,2311.08,2319.23,2331.58,2337.58,2351.3,2351.31,2351.16,2366.71,2365.13,2368.26,2367.34,2371.54,2367.79,2400.98,2394.75,2383.89,2378.8,2375.12,2373.09,2369.08,2376.86,2374.42,2368.55,2390.01,2388.1,2385.71,2379.55,2381.93,2351.81,2358.92,2356.22,2344.9,2363.78,2363.36,2370.42,2370.35,2365.87,2360.53,2378.36,2364.16,2363.76,2366.37,2355.22,2352.72,2348.26,2349.14,2348.35,2352.63,2361.37,2356.18,2376.98,2392.48,2398.16,2392.1,2393.68,2394.49,2392.93,2389.82,2391.43,2399.29,2401.36,2403.87,2399.74,2395.72,2392.44,2404.05,2405.77,2384.87,2375.74,2389.06,2395.46,2400.85,2405.58,2418.71,2416.68,2415.26,2415.99,2430.06,2440.23,2439.55,2436.21,2435.28,2439.27,2446.2,2430.38,2441.49,2443.75,2433.95,2433.15,2453.82,2450.66,2442.23,2441.62,2441.4,2450.42,2440.15,2442.97,2442.73,2432.71,2439.17,2434.9,2424.28,2426.92,2432.0,2429.3,2445.76,2449.32,2463.54,2462.82,2460.92,2473.83,2477.62,2472.54,2473.1,2481.24,2481.69,2484.04,2473.53,2477.96,2478.51,2480.38,2476.03,2480.0,2480.95,2490.87,2474.41,2465.38,2448.09,2468.22,2468.9,2474.93,2465.02,2440.27,2430.58,2454.77,2448.91,2450.39,2453.96,2449.12,2449.19,2460.31,2475.01,2480.38,2471.97,2469.64,2468.62,2467.11,2488.95,2496.77,2498.37,2498.43,2500.23,2508.32,2507.84,2508.85,2507.16,2503.47,2502.54,2503.51,25 ...

# %% [markdown]
# #### Gráfico de velas

# %%
trace = go.Candlestick(x=df_jun.index,
                       open=df_jun.Open,
                       high=df_jun.High,
                       low=df_jun.Low,
                       close=df_jun.Close)

data= [trace]
iplot(data)
# Out:
# <div>                            <div id="de0958ea-09c6-4ef6-97ae-cc7e0b75ce19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de0958ea-09c6-4ef6-97ae-cc7e0b75ce19")) {                    Plotly.newPlot(                        "de0958ea-09c6-4ef6-97ae-cc7e0b75ce19",                        [{"close":[2111.73,2109.6,2114.07,2095.84,2092.83,2079.28,2080.15,2105.2,2108.86,2094.11,2084.43,2096.29,2100.44,2121.24,2109.99,2122.85,2124.2,2108.58,2102.31,2101.49,2057.64,2063.11],"high":[2119.15,2117.59,2121.92,2112.89,2100.99,2093.01,2085.62,2108.5,2115.02,2107.43,2091.34,2097.4,2106.79,2126.65,2121.64,2129.87,2128.03,2125.1,2116.04,2108.92,2098.63,2074.28],"low":[2102.54,2099.14,2109.61,2093.23,2085.67,2079.11,2072.14,2081.12,2106.24,2091.33,2072.49,2082.1,2088.86,2101.58,2109.45,2112.5,2119.89,2108.58,2101.78,2095.38,2056.64,2056.32],"open":[2108.64,2110.41,2110.64,2112.35,2095.09,2092.34,2079.07,2081.12,2106.24,2107.43,2091.34,2084.26,2097.4,2101.58,2121.06,2112.5,2123.16,2123.65,2109.96,2102.62,2098.63,2061.19],"x":["2015-06-01T00:00:00","2015-06-02T00:00:00","2015-06-03T00:00:00","2015-06-04T00:00:00","2015-06-05T00:00:00","2015-06-08T00:00:00","2015-06-09T00:00:00","2015-06-10T00:00:00","2015-06-11T00:00:00","2015-06-12T00:00:00","2015-06-15T00:00:00","2015-06-16T00:00:00","2015-06-17T00:00:00","2015-06-18T00:00:00","2015-06-19T00:00:00","2015-06-22T00:00:00","2015-06-23T00:00:00","2015-06-24T00:00:00","2015-06-25T00:00:00","2015-06-26T00:00:00","2015-06-29T00:00:00","2015-06-30T00:00:00"],"type":"candlestick"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777777777 ...

# %% [markdown]
# ### Descomposición de series

# %%
rcParams['figure.figsize']=11,9
decomposed_sp_volume = sm.tsa.seasonal_decompose(df['Close'],period=180)
figure=decomposed_sp_volume.plot()
plt.grid()
plt.show()

# %% [markdown]
# ### Predicción simple - Medias moviles

# %%
train_len = 2500

train = df[0:train_len]
test = df[train_len:]

# %%
y_pred_sma = df.copy()
ma_window = 30
y_pred_sma['sma_forecast']=df['High'].rolling(ma_window).mean()
y_pred_sma['sma_forecast'][train_len]=y_pred_sma['sma_forecast'][train_len-1]
y_pred_sma
# Out:
# C:\Users\estef\AppData\Local\Temp\ipykernel_12824\2362070096.py:4: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\estef\AppData\Local\Temp\ipykernel_12824\2362070096.py:4: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#
# C:\Users\estef\AppData\Local\Temp\ipykernel_12824\2362070096.py:4: FutureWarning:
#
# Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#              Close    Open    High     Low  Change  Return  sma_forecast
# Date
# 2014-10-09 1928.21 1967.68 1967.68 1927.56     NaN     NaN           NaN
# 2014-10-10 1906.13 1925.63 1936.98 1906.05    0.99   -1.15           NaN
# 2014-10-13 1874.74 1905.65 1912.09 1874.14    0.98   -1.65           NaN
# 2014-10-14 1877.70 1877.11 1898.71 1871.79    1.00    0.16           NaN
# 2014-10-15 1862.49 1874.18 1874.18 1820.66    0.99   -0.81           NaN
# ...            ...     ...     ...     ...     ...     ...           ...
# 2024-10-02 5709.54 5698.14 5719.63 5674.00    1.00    0.01       5652.39
# 2024-10-03 5699.94 5698.19 5718.78 5677.37    1.00   -0.17       5655.26
# 2024-10-04 5751.07 5737.48 5753.21 5702.83    1.01    0.90       5658.93
# 2024-10-07 5695.94 5737.80 5739.34 5686.85    0.99   -0.96       5662.18
# 2024-10-08 5751.13 5719.14 5757.60 5714.56    1.01    0.97       5665.71
#
# [2527 rows x 7 columns]

# %%
# Gráfica de predicciones
plt.figure(figsize=(20,5))
plt.grid()
plt.plot(train['High'],label='Train')
plt.plot(test['High'],label='Test')
plt.plot(y_pred_sma['sma_forecast'],label='Predicción medias moviles')
plt.legend(loc='best')
plt.title('Predicicón simple con media movil')  
plt.show()

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(test['High'],y_pred_sma['sma_forecast'][train_len:])).round(2)
mape = np.round(np.mean(np.abs(test['High']-y_pred_sma['sma_forecast'][train_len:])/test['High'])*100,2)

results=pd.DataFrame({'Method':['Simple moving avarage forecast'],'MAPE':[mape],'RMSE':[rmse]})
results = results[['Method','RMSE','MAPE']]
results
# Out:
#                            Method   RMSE  MAPE
# 0  Simple moving avarage forecast 102.07  1.63
