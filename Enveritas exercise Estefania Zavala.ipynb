# %% [markdown]
# # Enveritas Exercise

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import os
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import gc
gc.collect
# Out:
# <function gc.collect(generation=2)>

# %% [markdown]
# ## Reading provided dataset

# %%
os.chdir('D:\FANNY\DOCUMENTOS\ANALISIS DE DATOS\Enveritas')

task_1 = pd.read_csv('task_1.csv')
task_3 = pd.read_csv('task_3.csv')

# %% [markdown]
# ## Task 1

# %%
task_1
# Out:
#            Region  Coffee farm size (hectares) Coffee form sold  \
# 0      antioquia1                         0.32           Cherry
# 1      antioquia1                         2.50           Cherry
# 2      antioquia1                         0.08    Dry Parchment
# 3      antioquia1                         0.10    Dry Parchment
# 4      antioquia1                         0.16    Dry Parchment
# ..            ...                          ...              ...
# 413  ejecafetero2                         2.00    Wet Parchment
# 414  ejecafetero2                         2.00    Wet Parchment
# 415  ejecafetero2                         4.00    Wet Parchment
# 416  ejecafetero2                         6.70    Wet Parchment
# 417  ejecafetero2                         8.32    Wet Parchment
#
#      Conversion (green)  Main Harvest  Second Harvest  Total Harvest  \
# 0               0.16000           1.0             0.5            1.5
# ...

# %%
task_1.groupby('Region')['Yield (kg green per hectare)'].mean()
# Out:
# Region
# antioquia1       1018.336418
# cundinamarca1    2315.148742
# ejecafetero1      789.462359
# ejecafetero2      985.776787
# Name: Yield (kg green per hectare), dtype: float64

# %%
# Average yield per region
avg_yield_per_region = task_1.groupby('Region')['Yield (kg green per hectare)'].mean().reset_index()

# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Yield (kg green per hectare)', data=avg_yield_per_region, palette='viridis')
plt.title('Average Yield per Region')
plt.xlabel('Region')
plt.ylabel('Average Yield (kg green per hectare)')
plt.xticks(rotation=45)  
plt.show()
# Out:
# C:\Users\estef\AppData\Local\Temp\ipykernel_17652\13510021.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Region', y='Yield (kg green per hectare)', data=avg_yield_per_region, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Coffee form sold', y='Yield (kg green per hectare)', data=task_1, palette='Set2')
plt.title('Yield vs Coffee Form Sold')
plt.xlabel('Coffee Form Sold')
plt.ylabel('Yield (kg green per hectare)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\estef\AppData\Local\Temp\ipykernel_17652\3871155699.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Coffee form sold', y='Yield (kg green per hectare)', data=task_1, palette='Set2')

# %%
import numpy as np
# Applying log transformation to make it easier to read
task_1['Log Yield'] = np.log1p(task_1['Yield (kg green per hectare)'])

# Plot with log-transformed data
plt.figure(figsize=(10, 6))
sns.boxplot(x='Coffee form sold', y='Log Yield', data=task_1, palette='Set2')
plt.title('Log-Transformed Yield vs Coffee Form Sold')
plt.xlabel('Coffee Form Sold')
plt.ylabel('Log Yield (kg green per hectare)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\estef\AppData\Local\Temp\ipykernel_17652\1207401810.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Coffee form sold', y='Log Yield', data=task_1, palette='Set2')

# %% [markdown]
# ## Task 3

# %%
task_3
# Out:
#         ID Coffee Region  Supply Unit             Pruning techniques used  \
# 0        1    Yirgachefe  dila_zuria1                                 NaN
# 1        2    Yirgachefe  dila_zuria1                                 NaN
# 2        3    Yirgachefe  dila_zuria1          branch_removal desuckering
# 3        4    Yirgachefe  dila_zuria1                                 NaN
# 4        5    Yirgachefe  dila_zuria1  branch_removal desuckering topping
# ...    ...           ...          ...                                 ...
# 2024  2025         Limmu        mana2                                 NaN
# 2025  2026         Limmu        mana2                                 NaN
# 2026  2027         Limmu        mana2                                 NaN
# 2027  2028         Limmu        mana2                                 NaN
# 2028  2029         Limmu        mana2                                 NaN
#
#      Use Disease Resistant Coffee Varieties Use Organic Fertilizer  \
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Use Disease Resistant Coffee Varieties', hue='Coffee Region', data=task_3, palette='viridis')
plt.title('Use of Disease Resistant Coffee Varieties by Region')
plt.xlabel('Use Disease Resistant Coffee Varieties')
plt.ylabel('Count')
plt.legend(title='Region')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Use Organic Fertilizer', hue='Coffee Region', data=task_3, palette='viridis')
plt.title('Use Organic Fertilizer')
plt.xlabel('Use Disease Resistant Coffee Varieties')
plt.ylabel('Count')
plt.legend(title='Region')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Intercrop food tree with coffee', hue='Coffee Region', data=task_3, palette='viridis')
plt.title('Intercrop food tree with coffee')
plt.xlabel('Intercrop food tree with coffee')
plt.ylabel('Count')
plt.legend(title='Region')
plt.show()

# %%
# Rows where pruning techniques are not empty
pruning_data = task_3[task_3['Pruning techniques used'].notnull()]

# Counting the occurrences of each pruning technique
pruning_techniques = pruning_data['Pruning techniques used'].str.split(' ', expand=True).stack().value_counts()

# Plot
plt.figure(figsize=(10, 6))
pruning_techniques.plot(kind='bar', color='skyblue')
plt.title('Most Common Pruning Techniques Used')
plt.ylabel('Frequency')
plt.xlabel('Pruning Technique')
plt.show()

# %%
plt.figure(figsize=(16, 10)) 
sns.boxplot(x='Pruning techniques used', y='Yield (kg/green) per hectare', data=task_3)
plt.title('Yield vs Pruning Techniques')
plt.xticks(rotation=45, ha='right')
plt.tight_layout() 
plt.show()

# %%
plt.figure(figsize=(16, 10))
sns.countplot(x='Coffee Region', hue='Pruning techniques used', data=task_3)
plt.title('Pruning Techniques by Region')
plt.xticks(rotation=45)
plt.show()
